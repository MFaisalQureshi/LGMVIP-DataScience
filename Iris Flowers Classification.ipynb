# %% [markdown]
# # Data Science Intern - LetsGrowMore
# ## Name: Faisal Qureshi
#
# ## Iris Flowers Classification ML Project :
# ### The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.
# ## Task 1 Basic Level:

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing Data

# %%
data=pd.read_csv('Iris.csv')
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Analyze the Data

# %%
data.shape
# Out:
# (150, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ## Fortunately data is In Cleaning Form Move On Data Visualization
# ## Data Visualization

# %%
sns.pairplot(data.drop("Id",axis=1),hue="Species",palette="husl")

# %%
sns.barplot(x="Species",y="PetalLengthCm",data=data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.barplot(x="Species",y="PetalWidthCm",data=data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
sns.barplot(x="Species",y="SepalLengthCm",data=data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.barplot(x="Species",y="SepalWidthCm",data=data)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.histplot(data['SepalLengthCm'],kde=True).set_title('SepalLengthCm Interval and Count')
# Out:
# Text(0.5, 1.0, 'SepalLengthCm Interval and Count')

# %%
sns.histplot(data['SepalWidthCm'],kde=True,color='red').set_title('SepalWidthCm Interval and Count')
# Out:
# Text(0.5, 1.0, 'SepalWidthCm Interval and Count')

# %%
sns.histplot(data['PetalLengthCm'],kde=True,color='green').set_title('PetalLengthCm Interval and Count')
# Out:
# Text(0.5, 1.0, 'PetalLengthCm Interval and Count')

# %%
sns.histplot(data['PetalWidthCm'],kde=True,color='yellow').set_title('PetalWidthCm Interval and Count')
# Out:
# Text(0.5, 1.0, 'PetalWidthCm Interval and Count')

# %% [markdown]
# ## Assign Species Name a Digit Number

# %%
data['Species']=data['Species'].replace({'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3})
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        3
# 146  147            6.3           2.5            5.0           1.9        3
# 147  148            6.5           3.0            5.2           2.0        3
# 148  149            6.2           3.4            5.4           2.3        3
# 149  150            5.9           3.0            5.1           1.8        3
#
# [150 rows x 6 columns]

# %%
X=data.drop(columns='Species')
y=data['Species']

# %% [markdown]
# ## Building Model Using Train_Test_Split Method

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 28    29            5.2           3.4            1.4           0.2
# 69    70            5.6           2.5            3.9           1.1
# 39    40            5.1           3.4            1.5           0.2
# 67    68            5.8           2.7            4.1           1.0
# 12    13            4.8           3.0            1.4           0.1
# ..   ...            ...           ...            ...           ...
# 84    85            5.4           3.0            4.5           1.5
# 114  115            5.8           2.8            5.1           2.4
# 8      9            4.4           2.9            1.4           0.2
# 51    52            6.4           3.2            4.5           1.5
# 10    11            5.4           3.7            1.5           0.2
#
# [105 rows x 5 columns]

# %%
y_train
# Out:
# 28     1
# 69     2
# 39     1
# 67     2
# 12     1
#       ..
# 84     2
# 114    3
# 8      1
# 51     2
# 10     1
# Name: Species, Length: 105, dtype: int64

# %% [markdown]
# ## 1 Apply Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\faisa\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([2, 2, 3, 2, 1, 3, 3, 1, 3, 3, 2, 3, 2, 1, 1, 2, 2, 3, 3, 1, 2, 2,
#        2, 2, 1, 3, 2, 1, 2, 1, 3, 1, 2, 3, 3, 1, 3, 2, 3, 3, 1, 2, 1, 2,
#        1], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ## Build Confusion Matrix

# %%
y_predicted=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  0, 15]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth or Actual Value')
# Out:
# Text(33.0, 0.5, 'Truth or Actual Value')

# %% [markdown]
# ## 2 Apply Decision Tree Classifier Model

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(max_depth=10,random_state=120,criterion='entropy')

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, random_state=120)

# %%
model.predict(X_test)
# Out:
# array([2, 2, 3, 2, 1, 3, 3, 1, 3, 3, 2, 3, 2, 1, 1, 2, 2, 3, 3, 1, 2, 2,
#        2, 2, 1, 3, 2, 1, 2, 1, 3, 1, 2, 3, 3, 2, 3, 2, 3, 3, 1, 2, 1, 2,
#        1], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.9777777777777777

# %% [markdown]
# ##  Build Confusion Matrix

# %%
y_predicted=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[12,  1,  0],
#        [ 0, 17,  0],
#        [ 0,  0, 15]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth Or Actual value')
# Out:
# Text(33.0, 0.5, 'Truth Or Actual value')

# %% [markdown]
# ## 3 Apply  Random Forest Classifier Model

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ## Build Confusion Matrix

# %%
y_predicted=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  0, 15]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth Or Actual value')
# Out:
# Text(33.0, 0.5, 'Truth Or Actual value')

# %% [markdown]
# ## 4 Apply SVM Model

# %%
from sklearn.svm import SVC
model=SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.predict(X_test)
# Out:
# array([2, 2, 3, 2, 1, 3, 3, 1, 3, 3, 2, 3, 2, 1, 1, 2, 2, 3, 3, 1, 2, 2,
#        2, 2, 1, 3, 2, 1, 2, 1, 3, 1, 2, 3, 3, 1, 3, 2, 3, 3, 1, 2, 1, 2,
#        1], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ## Build Confusion Matrix

# %%
y_predicted=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predicted)
cm
# Out:
# array([[13,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  0, 15]], dtype=int64)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth Or Actual value')
# Out:
# Text(33.0, 0.5, 'Truth Or Actual value')

# %% [markdown]
# ## 5 Apply Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.predict(X_test)
# Out:
# array([2, 2, 3, 2, 1, 3, 3, 1, 3, 3, 2, 3, 2, 1, 1, 2, 2, 3, 3, 1, 2, 2,
#        2, 2, 1, 3, 2, 1, 2, 1, 2, 1, 2, 3, 3, 1, 3, 2, 3, 3, 1, 2, 1, 2,
#        1], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.9777777777777777

# %% [markdown]
# ## Build Confusion Matrix

# %%
y_predicted=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predicted)

# %%
sns.heatmap(cm,annot=True)
plt.xlabel('Predicted Value')
plt.ylabel('Truth Or Actual value')
# Out:
# Text(33.0, 0.5, 'Truth Or Actual value')

# %% [markdown]
# ### Result: Here We See That Logistics Regression,Random Forest Classifier and Naive Bayes Perform with 100% Accuracy
